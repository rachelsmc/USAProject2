# %%
import pandas as pd
import os

try:
    import urllib2 as urllib
except ImportError:
    import urllib as urllib

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
url = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_180929.txt"
urllib.request.urlretrieve(url, "turnstile.csv")
# !mv turnstile.csv $HOME/USAProject2

# %%
turnstile = pd.read_csv(os.getenv('HOME') + '/USAProject2/turnstile.csv')

# %%
turnstile.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/22/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/22/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/22/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/22/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/22/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6767488
# 1  REGULAR  6767499
# 2  REGULAR  6767517
# 3  REGULAR  6767607
# 4  REGULAR  6767790
#
#    EXITS
# 0                                            2294227
# 1                                            2294230
# 2                                            2294258
# 3                                            2294323
# 4                                            2294368

# %%
unique(turnstile['STATION'])
# Out:
# array(['1 AV', '103 ST', '103 ST-CORONA', '104 ST', '110 ST', '111 ST',
#        '116 ST', '116 ST-COLUMBIA', '121 ST', '125 ST', '135 ST',
#        '137 ST CITY COL', '138/GRAND CONC', '14 ST', '14 ST-UNION SQ',
#        '145 ST', '149/GRAND CONC', '14TH STREET', '15 ST-PROSPECT',
#        '155 ST', '157 ST', '161/YANKEE STAD', '163 ST-AMSTERDM', '167 ST',
#        '168 ST', '169 ST', '170 ST', '174 ST', '175 ST', '176 ST', '18 AV',
#        '18 ST', '181 ST', '182-183 STS', '183 ST', '190 ST', '191 ST',
#        '2 AV', '20 AV', '207 ST', '21 ST', '21 ST-QNSBRIDGE', '215 ST',
#        '219 ST', '225 ST', '23 ST', '231 ST', '233 ST', '238 ST', '25 AV',
#        '25 ST', '28 ST', '3 AV', '3 AV 138 ST', '3 AV-149 ST', '30 AV',
#        '33 ST', '33 ST-RAWSON ST', '34 ST-HERALD SQ', '34 ST-HUDSON YD',
#        '34 ST-PENN STA', '36 AV', '36 ST', '4 AV-9 ST', '40 ST LOWERY ST',
#        '42 ST-BRYANT PK', '42 ST-PORT AUTH', '45 ST', '46 ST',
# ...

# %%
# want exits that occur after 8.00pm and before midnight

turnstile8pm = turnstile[turnstile['TIME'] ==  '00:00:00']
turnstile8pm0922 = turnstile8pm[turnstile8pm['DATE'] == '09/22/2018']
turnstile8pm0922.sort_values(by='UNIT')
# Out:
#           C/A  UNIT       SCP          STATION LINENAME DIVISION        DATE  \
# 38735    J025  R003  00-00-00    CYPRESS HILLS        J      BMT  09/22/2018
# 38777    J025  R003  00-00-01    CYPRESS HILLS        J      BMT  09/22/2018
# 38819    J025  R003  00-00-02    CYPRESS HILLS        J      BMT  09/22/2018
# 38990    J028  R004  00-00-03    75 ST-ELDERTS       JZ      BMT  09/22/2018
# 38861    J028  R004  00-00-00    75 ST-ELDERTS       JZ      BMT  09/22/2018
# 38904    J028  R004  00-00-01    75 ST-ELDERTS       JZ      BMT  09/22/2018
# 38947    J028  R004  00-00-02    75 ST-ELDERTS       JZ      BMT  09/22/2018
# 39033    J028  R004  00-00-04    75 ST-ELDERTS       JZ      BMT  09/22/2018
# 39162    J030  R005  00-00-02  85 ST-FOREST PK        J      BMT  09/22/2018
# 39205    J030  R005  00-00-03  85 ST-FOREST PK        J      BMT  09/22/2018
# 39076    J030  R005  00-00-00  85 ST-FOREST PK        J      BMT  09/22/2018
# ...

# %%
url = 'https://data.cityofnewyork.us/api/views/kk4q-3rt2/rows.csv?accessType=DOWNLOAD'
urllib.request.urlretrieve(url, "subwaystations.csv")
# !mv subwaystations.csv $HOME/USAProject2

# %%
stns = pd.read_csv(os.getenv('HOME') + '/USAProject2/subwaystations.csv')

# %%
stns = stns[['NAME', 'the_geom']]

# %%
stns.head()
# Out:
#                NAME                                      the_geom
# 0          Astor Pl  POINT (-73.99106999861966 40.73005400028978)
# 1          Canal St  POINT (-74.00019299927328 40.71880300107709)
# 2           50th St  POINT (-73.98384899986625 40.76172799961419)
# 3         Bergen St  POINT (-73.97499915116808 40.68086213682956)
# 4  Pennsylvania Ave  POINT (-73.89488591154061 40.66471445143568)

# %%
stns.shape
# Out:
# (473, 2)
